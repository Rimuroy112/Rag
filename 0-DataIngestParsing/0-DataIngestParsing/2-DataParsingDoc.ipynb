# %% [markdown]
# ### Word Document Processing

# %%
from docx import Document as DocxDocument
import os

# %%
from langchain_community.document_loaders import Docx2txtLoader, UnstructuredWordDocumentLoader
# Out:
# /tmp/ipykernel_883/3525976822.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import Docx2txtLoader, UnstructuredWordDocumentLoader

# %%
# Method 1: Docs2txtLoader
print("Docx2txtLoader")
try:
    docx_loader = Docx2txtLoader("data/word_files/proposal.docx")
    docx = docx_loader.load()
    print(f"Loaded {len(docx)} documents")
    print(f"Content preview: {docx[0].page_content[:200]}...")
    print(f"Metadata: docx[0].metadata")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Docx2txtLoader
# Loaded 1 documents
# Content preview: Project Proposal: RAG Implementation
#
# Executive Summary
#
# This proposal outlines the implementation of a Retrieval-Augmented Generation system for our organization.
#
# Objectives
#
# Key objectives include:...
# Metadata: docx[0].metadata
